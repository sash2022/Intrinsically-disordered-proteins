# %% [markdown]
# here we plot the density of water box versus the concentration of 1,6Hex in the box. thankGOD!

# %%
#new_itp/average of three separate runs of  0.9 and correct 0.8  thankGOD! thankGOD!
#water is  average
import numpy as np
import matplotlib.pyplot as plt

#  experiment
concentration = (0, 3, 11, 32, 54)  
density1 = (0.99704,0.99693,0.99668,0.99638,0.99618)  

# both*0.7 (1/1.1 * 0.8)
concentration = (0, 3, 11, 32, 54)  
density2 = (0.9970958,0.9972716,0.9961207, 0.9946331, 0.9937587)  

# average both*0.8 (1/1.1 * 0.9)
concentration = (0, 3, 11, 32, 54)  
density3 = (0.9970958,0.996736,0.99669456,0.9951414, 0.99419059)  

# average both*0.9 (1/1.1 * 1.0) Base line
concentration = (0, 3, 11, 32, 54)  
density4 = (0.9970958,0.9970862,0.996752, 0.9965349, 0.99604526)  

# average both*1.0 (1/1.1 * 1.1) baseline
concentration = (0, 3, 11, 32, 54)  
density5 = (0.9970958,0.99782615,0.9973562, 0.998342, 0.9989498)  

# both*1.1 (1/1.1 * 1.2)
concentration = (0, 3, 11, 32, 54)  
density6 = (0.9970958,0.99685535,0.9981007, 1.0001941, 1.0018392)  



# Plot both datasets on the same plot
plt.plot(concentration, density1, label='experiment', color='g')  # First plot in blue
plt.plot(concentration, density2, label='both*0.8', color='purple')
plt.plot(concentration, density3, label='average both*0.9', color='b')  
plt.plot(concentration, density4, label='average both*1.0', color='r')  
plt.plot(concentration, density5, label='average both*1.1', color='brown')  
plt.plot(concentration, density6, label='both*1.2', color='black')


plt.scatter(concentration,density1, c='g', s=50, alpha=0.5, edgecolor='black', zorder=5)  # Circles at the data points
plt.scatter(concentration,density2, c='purple', s=50, alpha=0.5, edgecolor='black', zorder=5)
plt.scatter(concentration,density3, c='b', s=50, alpha=0.5, edgecolor='black', zorder=5)  
plt.scatter(concentration,density4, c='r', s=50, alpha=0.5, edgecolor='black', zorder=5) 
plt.scatter(concentration,density5, c='brown', s=50, alpha=0.5, edgecolor='black', zorder=5) 
plt.scatter(concentration,density6, c='black', s=50, alpha=0.5, edgecolor='black', zorder=5)



# Add labels and title
plt.xlabel('Concentration (#1,6HD)')
plt.ylabel('Density')
plt.title('Concentration vs Density Plot')

# Add a legend to distinguish the two datasets
plt.legend()

# Add grid
plt.grid(True)

# Show the plot
plt.show()

# %%
# thankGOD! thankGOD! the same as above just a do not show the average to show to wenwei
#water is  average
import numpy as np
import matplotlib.pyplot as plt

#  experiment
concentration = (0, 3, 11, 32, 54)  
density1 = (0.99704,0.99693,0.99668,0.99638,0.99618)  

# both*0.7 (1/1.1 * 0.8)
concentration = (0, 3, 11, 32, 54)  
density2 = (0.9970958,0.9972716,0.9961207, 0.9946331, 0.9937587)  

# average both*0.8 (1/1.1 * 0.9)
concentration = (0, 3, 11, 32, 54)  
density3 = (0.9970958,0.996736,0.99669456,0.9951414, 0.99419059)  

# average both*0.9 (1/1.1 * 1.0) Base line
concentration = (0, 3, 11, 32, 54)  
density4 = (0.9970958,0.9970862,0.996752, 0.9965349, 0.99604526)  

# average both*1.0 (1/1.1 * 1.1) baseline
concentration = (0, 3, 11, 32, 54)  
density5 = (0.9970958,0.99782615,0.9973562, 0.998342, 0.9989498)  

# both*1.1 (1/1.1 * 1.2)
concentration = (0, 3, 11, 32, 54)  
density6 = (0.9970958,0.99685535,0.9981007, 1.0001941, 1.0018392)  



# Plot both datasets on the same plot
plt.plot(concentration, density1, label='experiment', color='g')  # First plot in blue
plt.plot(concentration, density2, label='eps*0.8', color='purple')
plt.plot(concentration, density3, label='esp*0.9', color='b')  
plt.plot(concentration, density4, label='eps*1.0', color='r')  
plt.plot(concentration, density5, label='eps*1.1', color='brown')  
plt.plot(concentration, density6, label='eps*1.2', color='black')


plt.scatter(concentration,density1, c='g', s=50, alpha=0.5, edgecolor='black', zorder=5)  # Circles at the data points
plt.scatter(concentration,density2, c='purple', s=50, alpha=0.5, edgecolor='black', zorder=5)
plt.scatter(concentration,density3, c='b', s=50, alpha=0.5, edgecolor='black', zorder=5)  
plt.scatter(concentration,density4, c='r', s=50, alpha=0.5, edgecolor='black', zorder=5) 
plt.scatter(concentration,density5, c='brown', s=50, alpha=0.5, edgecolor='black', zorder=5) 
plt.scatter(concentration,density6, c='black', s=50, alpha=0.5, edgecolor='black', zorder=5)



# Add labels and title
plt.xlabel('Concentration (#1,6HD)')
plt.ylabel('Density')
plt.title('Concentration vs Density Plot')

# Add a legend to distinguish the two datasets
plt.legend()

# Add grid
plt.grid(True)

# Show the plot
plt.show()
